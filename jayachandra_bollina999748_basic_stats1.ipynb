# %% [markdown]
# <a href="https://colab.research.google.com/github/jayachandra369/DS_assignments/blob/main/jayachandra_bollina999748_basic_stats1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('sales_data_with_discounts.csv')

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.median(numeric_only=True)
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
# Create a figure and axes for the subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 4))  # Adjust figsize as needed

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate through numeric columns and create histograms
for i, column in enumerate(df.select_dtypes(include=np.number).columns):
  if i < len(axes):  # Ensure we don't exceed the number of axes
    sns.histplot(data=df, x=column, ax=axes[i], bins=20)  # Adjust bins as needed
    axes[i].set_title(f'Histogram of {column}')

# Remove any unused axes
for i in range(len(df.select_dtypes(include=np.number).columns), len(axes)):
    fig.delaxes(axes[i])


plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
# prompt: Provide box plots for above with same template of output

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('sales_data_with_discounts.csv')
df.describe()
df.median(numeric_only=True)
df.mode(numeric_only=True)


# Create a figure and axes for the subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 4))  # Adjust figsize as needed

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate through numeric columns and create box plots
for i, column in enumerate(df.select_dtypes(include=np.number).columns):
  if i < len(axes):  # Ensure we don't exceed the number of axes
    sns.boxplot(data=df, x=column, ax=axes[i])
    axes[i].set_title(f'Box Plot of {column}')

# Remove any unused axes
for i in range(len(df.select_dtypes(include=np.number).columns), len(axes)):
    fig.delaxes(axes[i])


plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
# prompt: Provide bar charts for above categorical coluimns

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('sales_data_with_discounts.csv')

# Identify categorical columns (excluding 'City')
categorical_cols = [col for col in df.columns if df[col].dtype == 'object' and col != 'City']

# Create a matrix of subplots for bar charts
num_cols = len(categorical_cols)
rows = (num_cols + 2) // 3  # Calculate number of rows needed
cols = min(num_cols, 3)

fig, axes = plt.subplots(rows, cols, figsize=(10, 2.25 * rows))
axes = axes.flatten()

# Iterate through categorical columns and create bar charts
for i, col in enumerate(categorical_cols):
  if i < len(axes):
    df[col].value_counts().plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'Bar Chart of {col}')
    axes[i].tick_params(axis='x', rotation=45, labelsize=8)  # Rotate x-axis labels for better visibility

# Remove any unused axes
for i in range(len(categorical_cols), len(axes)):
  fig.delaxes(axes[i])


plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('sales_data_with_discounts.csv')

# Identify numerical columns
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

# Before Standardization: Plot histograms
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns):
    plt.subplot(2, 3, i + 1)
    plt.hist(data[column], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Standardize numerical columns
data_standardized = data.copy()
for column in numerical_columns:
    mu = data[column].mean()
    sigma = data[column].std()
    data_standardized[column] = (data[column] - mu) / sigma

# After Standardization: Plot histograms
plt.figure(figsize=(10, 4))
for i, column in enumerate(numerical_columns):
    plt.subplot(2, 3, i + 1)
    plt.hist(data_standardized[column], bins=30, color='lightgreen', edgecolor='black')
    plt.title(f'{column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('sales_data_with_discounts.csv')

# Select categorical columns
categorical_columns = ['Day', 'SKU', 'City', 'BU', 'Brand', 'Model']

# Apply one-hot encoding
df_encoded = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# Display the first few rows of the transformed dataset
print(df_encoded.head())

# Display the shape of the new dataset
print("\nShape of the encoded dataset:", df_encoded.shape)
# Out:
#          Date  Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0  01-04-2021      15      12100             181500          11.654820
# 1  01-04-2021      10      10100             101000          11.560498
# 2  01-04-2021       7      16100             112700           9.456886
# 3  01-04-2021       6      20100             120600           6.935385
# 4  01-04-2021       3       8100              24300          17.995663
#
#    Discount Amount  Net Sales Value  Day_Monday  Day_Saturday  Day_Sunday  \
# 0     21153.498820    160346.501180       False         False       False
# 1     11676.102961     89323.897039       False         False       False
# 2     10657.910157    102042.089843       False         False       False
# 3      8364.074702    112235.925298       False         False       False
# 4      4372.946230     19927.053770       False         False       False
#
#    ...  Model_Vedic Cream  Model_Vedic Oil  Model_Vedic Shampoo  \
# ...
